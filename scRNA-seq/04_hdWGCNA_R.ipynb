# %% [markdown]
# Running R codes here seems to be a bitch.
# To use R codes here, install rpy2 using `mamba install rpy2`

# %% [markdown]
# I already have an R project with "renv" that I want to use.

# %%
import os

# Set R_LIBS before importing rpy2
renv_library_path = "/home/momo/R/Projects/ABCA/renv/library/linux-ubuntu-jammy/R-4.4"
os.environ["R_LIBS"] = renv_library_path
os.environ["R_HOME"] = "/home/momo/R/Projects/ABCA/renv/library/linux-ubuntu-jammy/R-4.4"

# Import rpy2.robjects after setting the environment
import rpy2.robjects as ro

# Explicitly reset .libPaths() in R
ro.r(f'.libPaths(c("{renv_library_path}"))')

# Verify the R version and library paths
print(ro.r('R.version.string'))
print(ro.r('.libPaths()'))
# Out:
# Unable to determine R library path: [Errno 2] No such file or directory: '/home/momo/R/Projects/ABCA/renv/library/linux-ubuntu-jammy/R-4.4/bin/Rscript'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import rpy2.robjects as ro
# %load_ext rpy2.ipython

# %%
# %%R
# library(renv)
# setwd("/home/momo/R/Projects/ABCA/")
# renv::activate()
# Out:
# R[write to console]: Error in library(renv) : there is no package called ‘renv’
# Error in library(renv) : there is no package called ‘renv’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:385, in RMagics.eval(self, code)
#     383 try:
#     384     # Need the newline in case the last line in code is a comment.
# --> 385     value, visible = ro.r("withVisible({%s\n})" % code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in library(renv) : there is no package called ‘renv’
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', 'library(renv)\nsetwd("/home/momo/R/Projects/ABCA/")\nrenv::activate()\n')
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:943, in RMagics.R(self, line, cell, local_ns)
#     941     if not e.stdout.endswith(e.err):
#     942         print(e.err)
# --> 943     raise e
#     944 finally:
#     945     if self.device in DEVICES_STATIC:
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:923, in RMagics.R(self, line, cell, local_ns)
#     921         return_output = False
#     922 else:
# --> 923     text_result, result, visible = self.eval(code)
#     924     text_output += text_result
#     925     if visible:
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:389, in RMagics.eval(self, code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#     388     warning_or_other_msg = self.flush()
# --> 389     raise RInterpreterError(code, str(exception),
#     390                             warning_or_other_msg)
#     391 text_output = self.flush()
#     392 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line 'library(renv)\nsetwd("/home/momo/R/Projects/ABCA/")\nrenv::activate()\n'.
# R error message: 'Error in library(renv) : there is no package called ‘renv’'

# %%
print(ro.r('R.home()'))
# Out:
# [1] "/home/momo/miniforge3/envs/abca-env/lib/R"

# %%
# Activate renv within the R session
ro.r(f'''
library(renv)
renv::activate("{'/home/momo/R/Projects/ABCA'}")
''')
# Out:
# R[write to console]: Error in library(renv) : there is no package called ‘renv’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Activate renv within the R session
# ----> 2 ro.r(f'''
#       3 library(renv)
#       4 renv::activate("{'/home/momo/R/Projects/ABCA'}")
#       5 ''')
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     457 def __call__(self, string):
#     458     p = rinterface.parse(string)
# --> 459     res = self.eval(p)
#     460     return conversion.get_conversion().rpy2py(res)
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     206         v = kwargs.pop(k)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     129     else:
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#     133 return res
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     810     res = rmemory.protect(
#     811         openrlib.rlib.R_tryEval(
#     812             call_r,
#     813             call_context.__sexp__._cdata,
#     814             error_occured)
#     815     )
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in library(renv) : there is no package called ‘renv’

# %%
# expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-log2-wmeta.h5ad'
expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-log2-wmeta.h5ad'
adata = sc.read_h5ad(expr_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 227670 × 32285
#     obs: 'cell_barcode', 'barcoded_cell_sample_label', 'library_label', 'feature_matrix_label', 'entity', 'brain_section_label', 'library_method', 'region_of_interest_acronym', 'donor_label', 'donor_genotype', 'donor_sex', 'dataset_label', 'x', 'y', 'cluster_alias', 'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color', 'class_color', 'subclass_color', 'supertype_color', 'cluster_color', 'region_of_interest_order', 'region_of_interest_color'
#     var: 'gene_symbol'

# %%
def print_column_info(df):
    for c in df.columns:
        # Explicitly set observed=False to retain current behavior and suppress the warning
        grouped = df[[c]].groupby(c, observed=False).count()
        members = ''
        if len(grouped) < 30:
            members = str(list(grouped.index))
        print(f"Number of unique {c} = {len(grouped)} {members}")

# %%
print_column_info(adata.obs)
# Out:
# Number of unique cell_barcode = 220576
# Number of unique barcoded_cell_sample_label = 68
# Number of unique library_label = 68
# Number of unique feature_matrix_label = 1 ['WMB-10Xv3-Isocortex-1']
# Number of unique entity = 1 ['cell']
# Number of unique brain_section_label = 0 []
# Number of unique library_method = 1 ['10Xv3']
# Number of unique region_of_interest_acronym = 10 ['ACA', 'AI', 'AUD-TEa-PERI-ECT', 'MO-FRP', 'MOp', 'PL-ILA-ORB', 'RSP', 'SS-GU-VISC', 'VIS', 'VIS-PTLp']
# Number of unique donor_label = 36
# Number of unique donor_genotype = 2 ['Ai14(RCL-tdT)/wt', 'Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt']
# Number of unique donor_sex = 2 ['F', 'M']
# Number of unique dataset_label = 1 ['WMB-10Xv3']
# Number of unique x = 226998
# Number of unique y = 227247
# Number of unique cluster_alias = 677
# Number of unique neurotransmitter = 8 ['Chol', 'Dopa', 'GABA', 'GABA-Glyc', 'Glut', 'Glut-GABA', 'Hist', 'Nora']
# Number of unique class = 24 ['01 IT-ET Glut', '02 NP-CT-L6b Glut', '03 OB-CR Glut', '04 DG-IMN Glut', '05 OB-IMN GABA', '06 CTX-CGE GABA', '07 CTX-MGE GABA', '08 CNU-MGE GABA', '09 CNU-LGE GABA', '10 LSX GABA', '11 CNU-HYa GABA', '12 HY GABA', '13 CNU-HYa Glut', '14 HY Glut', '15 HY Gnrh1 Glut', '16 HY MM Glut', '24 MY Glut', '25 Pineal Glut', '27 MY GABA', '30 Astro-Epen', '31 OPC-Oligo', '32 OEC', '33 Vascular', '34 Immune']
# Number of unique subclass = 112
# Number of unique supertype = 287
# Number of unique cluster = 677
# Number of unique neurotransmitter_color = 9 ['#0a9964', '#2B93DF', '#03EDFF', '#73E785', '#820e57', '#666666', '#FF3358', '#fcf04b', '#ff7621']
# Number of unique class_color = 24 ['#1b4332', '#01d669', '#16f2f2', '#61e2a4', '#70E000', '#90E0EF', '#0096C7', '#594a26', '#825f45', '#996B2E', '#03045E', '#3283FE', '#086375', '#450099', '#858881', '#AA0DFE', '#B199FF', '#CCFF33', '#D00000', '#F0A0FF', '#F28266', '#FA0087', '#FF6600', '#f954ee']
# Number of unique subclass_color = 112
# Number of unique supertype_color = 287
# Number of unique cluster_color = 677
# Number of unique region_of_interest_order = 10 [0, 1, 2, 5, 6, 7, 8, 9, 10, 11]
# Number of unique region_of_interest_color = 10 ['#2E8599', '#3DCC7C', '#6F9945', '#8CCC00', '#26AEFF', '#0059CC', '#84FF4D', '#00990A', '#179968', '#E4FF26']

# %%
def plot_umap(xx, yy, cc=None, val=None, fig_width=8, fig_height=8, cmap=None):

    fig, ax = plt.subplots()
    fig.set_size_inches(fig_width, fig_height)
    
    if cmap is not None :
        plt.scatter(xx, yy, s=0.5, c=val, marker='.', cmap=cmap)
    elif cc is not None :
        plt.scatter(xx, yy, s=0.5, color=cc, marker='.')
        
    ax.axis('equal')
    ax.set_xlim(-18, 27)
    ax.set_ylim(-18, 27)
    ax.set_xticks([])
    ax.set_yticks([])
    
    return fig, ax

# %%
cell_subsampled = adata.obs
print(len(cell_subsampled))
# Out:
# 227670

# %%
fig, ax = plot_umap(cell_subsampled['x'], cell_subsampled['y'], cc=cell_subsampled['region_of_interest_color'])
res = ax.set_title("Dissection Region Of Interest")
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
fig, ax = plot_umap(cell_subsampled['x'], cell_subsampled['y'], cc=cell_subsampled['neurotransmitter_color'])
res = ax.set_title("Neurotransmitter Identity")
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
fig, ax = plot_umap(cell_subsampled['x'], cell_subsampled['y'], cc=cell_subsampled['class_color'])
res = ax.set_title("Cell Types: Class")
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
fig, ax = plot_umap(cell_subsampled['x'], cell_subsampled['y'], cc=cell_subsampled['subclass_color'])
res = ax.set_title("Cell Types: Subclass")
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
