# %% [markdown]
# First, install scanpy using `mamba install -c conda-forge scanpy`

# %%
import anndata
import scanpy as sc
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
download_base = Path('/data/scRNA/ABCA/AIBS/AWS/')
abc_cache = AbcProjectCache.from_cache_dir(download_base)
# Out:
# /home/momo/miniforge3/envs/abca-env/lib/python3.10/site-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:630: OutdatedManifestWarning: You are loading releases/20241130/manifest.json. A more up to date version of the dataset -- releases/20250131/manifest.json -- exists online. To see the changes between the two versions of the dataset, run
# type.compare_manifests('releases/20241130/manifest.json', 'releases/20250131/manifest.json')
# To load another version of the dataset, run
# type.load_manifest('releases/20250131/manifest.json')
#   warnings.warn(msg, OutdatedManifestWarning)

# %%
cell_metadata = abc_cache.get_metadata_dataframe(
    directory='WMB-10X',
    file_name='cell_metadata_with_cluster_annotation'
)
cell_metadata.set_index('cell_label', inplace=True)
# Out:
# /home/momo/miniforge3/envs/abca-env/lib/python3.10/site-packages/abc_atlas_access/abc_atlas_cache/abc_project_cache.py:429: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path, **kwargs)

# %%
cell_metadata.head()
# Out:
#                               cell_barcode barcoded_cell_sample_label  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05  GCGAGAAGTTAAGGGC                    410_B05
# AATGGCTCAGCTCCTT-411_B06  AATGGCTCAGCTCCTT                    411_B06
# AACACACGTTGCTTGA-410_B05  AACACACGTTGCTTGA                    410_B05
# CACAGATAGAGGCGGA-410_A05  CACAGATAGAGGCGGA                    410_A05
# AAAGTGAAGCATTTCG-410_B05  AAAGTGAAGCATTTCG                    410_B05
#
#                                library_label feature_matrix_label entity  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05  L8TX_201030_01_C12        WMB-10Xv3-HPF   cell
# AATGGCTCAGCTCCTT-411_B06  L8TX_201029_01_E10        WMB-10Xv3-HPF   cell
# AACACACGTTGCTTGA-410_B05  L8TX_201030_01_C12        WMB-10Xv3-HPF   cell
# CACAGATAGAGGCGGA-410_A05  L8TX_201029_01_A10        WMB-10Xv3-HPF   cell
# AAAGTGAAGCATTTCG-410_B05  L8TX_201030_01_C12        WMB-10Xv3-HPF   cell
#
#                           brain_section_label library_method  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05                  NaN          10Xv3
# AATGGCTCAGCTCCTT-411_B06                  NaN          10Xv3
# AACACACGTTGCTTGA-410_B05                  NaN          10Xv3
# CACAGATAGAGGCGGA-410_A05                  NaN          10Xv3
# AAAGTGAAGCATTTCG-410_B05                  NaN          10Xv3
#
#                          region_of_interest_acronym  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05                        RHP
# AATGGCTCAGCTCCTT-411_B06                        RHP
# AACACACGTTGCTTGA-410_B05                        RHP
# CACAGATAGAGGCGGA-410_A05                        RHP
# AAAGTGAAGCATTTCG-410_B05                        RHP
#
#                                            donor_label    donor_genotype  ...  \
# cell_label                                                                ...
# GCGAGAAGTTAAGGGC-410_B05  Snap25-IRES2-Cre;Ai14-550850  Ai14(RCL-tdT)/wt  ...
# AATGGCTCAGCTCCTT-411_B06  Snap25-IRES2-Cre;Ai14-550851  Ai14(RCL-tdT)/wt  ...
# AACACACGTTGCTTGA-410_B05  Snap25-IRES2-Cre;Ai14-550850  Ai14(RCL-tdT)/wt  ...
# CACAGATAGAGGCGGA-410_A05  Snap25-IRES2-Cre;Ai14-550850  Ai14(RCL-tdT)/wt  ...
# AAAGTGAAGCATTTCG-410_B05  Snap25-IRES2-Cre;Ai14-550850  Ai14(RCL-tdT)/wt  ...
#
#                                         subclass                  supertype  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05  018 L2 IT PPP-APr Glut  0082 L2 IT PPP-APr Glut_3
# AATGGCTCAGCTCCTT-411_B06  018 L2 IT PPP-APr Glut  0082 L2 IT PPP-APr Glut_3
# AACACACGTTGCTTGA-410_B05  018 L2 IT PPP-APr Glut  0082 L2 IT PPP-APr Glut_3
# CACAGATAGAGGCGGA-410_A05  018 L2 IT PPP-APr Glut  0082 L2 IT PPP-APr Glut_3
# AAAGTGAAGCATTTCG-410_B05  018 L2 IT PPP-APr Glut  0082 L2 IT PPP-APr Glut_3
#
#                                             cluster  neurotransmitter_color  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05  0326 L2 IT PPP-APr Glut_3                 #2B93DF
# AATGGCTCAGCTCCTT-411_B06  0326 L2 IT PPP-APr Glut_3                 #2B93DF
# AACACACGTTGCTTGA-410_B05  0326 L2 IT PPP-APr Glut_3                 #2B93DF
# CACAGATAGAGGCGGA-410_A05  0326 L2 IT PPP-APr Glut_3                 #2B93DF
# AAAGTGAAGCATTTCG-410_B05  0326 L2 IT PPP-APr Glut_3                 #2B93DF
#
#                           class_color subclass_color supertype_color  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05      #FA0087        #0F6632         #266DFF
# AATGGCTCAGCTCCTT-411_B06      #FA0087        #0F6632         #266DFF
# AACACACGTTGCTTGA-410_B05      #FA0087        #0F6632         #266DFF
# CACAGATAGAGGCGGA-410_A05      #FA0087        #0F6632         #266DFF
# AAAGTGAAGCATTTCG-410_B05      #FA0087        #0F6632         #266DFF
#
#                          cluster_color region_of_interest_order  \
# cell_label
# GCGAGAAGTTAAGGGC-410_B05       #64661F                       15
# AATGGCTCAGCTCCTT-411_B06       #64661F                       15
# AACACACGTTGCTTGA-410_B05       #64661F                       15
# CACAGATAGAGGCGGA-410_A05       #64661F                       15
# AAAGTGAAGCATTTCG-410_B05       #64661F                       15
#
#                          region_of_interest_color
# cell_label
# GCGAGAAGTTAAGGGC-410_B05                  #CCB05C
# AATGGCTCAGCTCCTT-411_B06                  #CCB05C
# AACACACGTTGCTTGA-410_B05                  #CCB05C
# CACAGATAGAGGCGGA-410_A05                  #CCB05C
# AAAGTGAAGCATTTCG-410_B05                  #CCB05C
#
# [5 rows x 27 columns]

# %%
# expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-log2.h5ad'
# expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-log2.h5ad'
# expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-raw.h5ad'
expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-raw.h5ad'
expression_data = sc.read_h5ad(expr_path)
expression_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 # expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-log2.h5ad'
#       2 # expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-log2.h5ad'
#       3 # expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-raw.h5ad'
#       4 expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-raw.h5ad'
# ----> 5 expression_data = sc.read_h5ad(expr_path)
#       6 expression_data
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/anndata/_io/h5ad.py:236, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     228         raise NotImplementedError(
#     229             "Currently only `X` and `raw/X` can be read as sparse."
#     230         )
#     232 rdasp = partial(
#     233     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     234 )
# --> 236 with h5py.File(filename, "r") as f:
#     238     def callback(func, elem_name: str, elem, iospec):
#     239         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File ~/miniforge3/envs/abca-env/lib/python3.10/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-raw.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
expression_data.obs.head()
# Out:
#                               cell_barcode       library_label  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  GCCCGAAGTCAGTTTG  L8TX_200827_01_E10
# AGGTTACTCGCGCCAA-332_B01  AGGTTACTCGCGCCAA  L8TX_200820_01_D01
# ATGAGGGAGTGTTCCA-332_A01  ATGAGGGAGTGTTCCA  L8TX_200820_01_E02
# CATAGACAGTCTAACC-299_B02  CATAGACAGTCTAACC  L8TX_200723_01_G09
# GAGTTACCATGACGAG-299_A02  GAGTTACCATGACGAG  L8TX_200723_01_F09
#
#                          anatomical_division_label
# cell_label
# GCCCGAAGTCAGTTTG-344_C04                     CTXsp
# AGGTTACTCGCGCCAA-332_B01                     CTXsp
# ATGAGGGAGTGTTCCA-332_A01                     CTXsp
# CATAGACAGTCTAACC-299_B02                     CTXsp
# GAGTTACCATGACGAG-299_A02                     CTXsp

# %%
expression_data.obs_names
# Out:
# Index(['GCCCGAAGTCAGTTTG-344_C04', 'AGGTTACTCGCGCCAA-332_B01',
#        'ATGAGGGAGTGTTCCA-332_A01', 'CATAGACAGTCTAACC-299_B02',
#        'GAGTTACCATGACGAG-299_A02', 'GGAGCAATCTCTCGAC-299_A02',
#        'GGCTTGGTCTCCGAGG-332_B01', 'TCGAAGTGTTCGGTCG-308_B03',
#        'GAGACTTAGTGCCCGT-308_A03', 'AGCCAATAGTAGCCAG-344_B04',
#        ...
#        'TTTGGTTTCAGGACGA-344_C04', 'TTTGGTTTCCCAGTGG-323_A02',
#        'TTTGGTTTCCGCACGA-308_A03', 'TTTGTTGAGAGCACTG-332_C01',
#        'TTTGTTGCACTGGACC-341_A01', 'TTTGTTGGTCCCTAAA-344_A04',
#        'TTTGTTGGTGAGCGAT-308_C03', 'TTTGTTGGTTGTGGCC-308_C03',
#        'TTTGTTGTCTAAGCCA-332_C01', 'TTTGTTGTCTTACGGA-341_A01'],
#       dtype='object', name='cell_label', length=78464)

# %%
# Align metadata with expression data
common_cells = expression_data.obs_names.intersection(cell_metadata.index)
expression_data = expression_data[common_cells, :]

# Add metadata to the AnnData object
expression_data.obs = cell_metadata.loc[common_cells]
expression_data
# Out:
# AnnData object with n_obs × n_vars = 78223 × 32285
#     obs: 'cell_barcode', 'barcoded_cell_sample_label', 'library_label', 'feature_matrix_label', 'entity', 'brain_section_label', 'library_method', 'region_of_interest_acronym', 'donor_label', 'donor_genotype', 'donor_sex', 'dataset_label', 'x', 'y', 'cluster_alias', 'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color', 'class_color', 'subclass_color', 'supertype_color', 'cluster_color', 'region_of_interest_order', 'region_of_interest_color'
#     var: 'gene_symbol'
#     uns: 'normalization', 'parent', 'parent_layer', 'parent_rows'

# %%
expression_data.obs.head()
# Out:
#                               cell_barcode barcoded_cell_sample_label  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  GCCCGAAGTCAGTTTG                    344_C04
# AGGTTACTCGCGCCAA-332_B01  AGGTTACTCGCGCCAA                    332_B01
# ATGAGGGAGTGTTCCA-332_A01  ATGAGGGAGTGTTCCA                    332_A01
# CATAGACAGTCTAACC-299_B02  CATAGACAGTCTAACC                    299_B02
# GAGTTACCATGACGAG-299_A02  GAGTTACCATGACGAG                    299_A02
#
#                                library_label feature_matrix_label entity  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  L8TX_200827_01_E10      WMB-10Xv3-CTXsp   cell
# AGGTTACTCGCGCCAA-332_B01  L8TX_200820_01_D01      WMB-10Xv3-CTXsp   cell
# ATGAGGGAGTGTTCCA-332_A01  L8TX_200820_01_E02      WMB-10Xv3-CTXsp   cell
# CATAGACAGTCTAACC-299_B02  L8TX_200723_01_G09      WMB-10Xv3-CTXsp   cell
# GAGTTACCATGACGAG-299_A02  L8TX_200723_01_F09      WMB-10Xv3-CTXsp   cell
#
#                           brain_section_label library_method  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04                  NaN          10Xv3
# AGGTTACTCGCGCCAA-332_B01                  NaN          10Xv3
# ATGAGGGAGTGTTCCA-332_A01                  NaN          10Xv3
# CATAGACAGTCTAACC-299_B02                  NaN          10Xv3
# GAGTTACCATGACGAG-299_A02                  NaN          10Xv3
#
#                          region_of_interest_acronym  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04                      CTXsp
# AGGTTACTCGCGCCAA-332_B01                      CTXsp
# ATGAGGGAGTGTTCCA-332_A01                      CTXsp
# CATAGACAGTCTAACC-299_B02                      CTXsp
# GAGTTACCATGACGAG-299_A02                      CTXsp
#
#                                            donor_label  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  Snap25-IRES2-Cre;Ai14-539605
# AGGTTACTCGCGCCAA-332_B01  Snap25-IRES2-Cre;Ai14-537272
# ATGAGGGAGTGTTCCA-332_A01  Snap25-IRES2-Cre;Ai14-537272
# CATAGACAGTCTAACC-299_B02  Snap25-IRES2-Cre;Ai14-532618
# GAGTTACCATGACGAG-299_A02  Snap25-IRES2-Cre;Ai14-532618
#
#                                                 donor_genotype  ...  \
# cell_label                                                      ...
# GCCCGAAGTCAGTTTG-344_C04  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# AGGTTACTCGCGCCAA-332_B01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# ATGAGGGAGTGTTCCA-332_A01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# CATAGACAGTCTAACC-299_B02  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# GAGTTACCATGACGAG-299_A02  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
#
#                                                subclass  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  079 CEA-BST Six3 Cyp26b1 Gaba
# AGGTTACTCGCGCCAA-332_B01  079 CEA-BST Six3 Cyp26b1 Gaba
# ATGAGGGAGTGTTCCA-332_A01  080 CEA-AAA-BST Six3 Sp9 Gaba
# CATAGACAGTCTAACC-299_B02  080 CEA-AAA-BST Six3 Sp9 Gaba
# GAGTTACCATGACGAG-299_A02  080 CEA-AAA-BST Six3 Sp9 Gaba
#
#                                                  supertype  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  0367 CEA-BST Six3 Cyp26b1 Gaba_1
# AGGTTACTCGCGCCAA-332_B01  0367 CEA-BST Six3 Cyp26b1 Gaba_1
# ATGAGGGAGTGTTCCA-332_A01  0374 CEA-AAA-BST Six3 Sp9 Gaba_2
# CATAGACAGTCTAACC-299_B02  0374 CEA-AAA-BST Six3 Sp9 Gaba_2
# GAGTTACCATGACGAG-299_A02  0374 CEA-AAA-BST Six3 Sp9 Gaba_2
#
#                                                    cluster  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04  1327 CEA-BST Six3 Cyp26b1 Gaba_1
# AGGTTACTCGCGCCAA-332_B01  1330 CEA-BST Six3 Cyp26b1 Gaba_1
# ATGAGGGAGTGTTCCA-332_A01  1358 CEA-AAA-BST Six3 Sp9 Gaba_2
# CATAGACAGTCTAACC-299_B02  1358 CEA-AAA-BST Six3 Sp9 Gaba_2
# GAGTTACCATGACGAG-299_A02  1358 CEA-AAA-BST Six3 Sp9 Gaba_2
#
#                           neurotransmitter_color  class_color subclass_color  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04                 #FF3358      #450099        #73C1FF
# AGGTTACTCGCGCCAA-332_B01                 #FF3358      #450099        #73C1FF
# ATGAGGGAGTGTTCCA-332_A01                 #FF3358      #450099        #990091
# CATAGACAGTCTAACC-299_B02                 #FF3358      #450099        #990091
# GAGTTACCATGACGAG-299_A02                 #FF3358      #450099        #990091
#
#                          supertype_color cluster_color  \
# cell_label
# GCCCGAAGTCAGTTTG-344_C04         #660F30       #FFED73
# AGGTTACTCGCGCCAA-332_B01         #660F30       #814DFF
# ATGAGGGAGTGTTCCA-332_A01         #57662E       #662E4F
# CATAGACAGTCTAACC-299_B02         #57662E       #662E4F
# GAGTTACCATGACGAG-299_A02         #57662E       #662E4F
#
#                          region_of_interest_order region_of_interest_color
# cell_label
# GCCCGAAGTCAGTTTG-344_C04                       17                  #994817
# AGGTTACTCGCGCCAA-332_B01                       17                  #994817
# ATGAGGGAGTGTTCCA-332_A01                       17                  #994817
# CATAGACAGTCTAACC-299_B02                       17                  #994817
# GAGTTACCATGACGAG-299_A02                       17                  #994817
#
# [5 rows x 27 columns]

# %%
# Saving to file
# save_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-log2-wmeta.h5ad'
# save_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-Isocortex-1-log2-wmeta.h5ad'
save_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv3/20230630/WMB-10Xv3-CTXsp-raw-wmeta.h5ad'
expression_data.write_h5ad(save_path)
