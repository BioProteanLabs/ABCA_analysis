# %%
import anndata as ad
import seaborn as sns
import numpy as np
import scanpy as sc
import pandas as pd
import gc
from pathlib import Path
import matplotlib.pyplot as plt
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
# getting all microglia data
download_base = Path('/data/scRNA/ABCA/AIBS/AWS/')
abc_cache = AbcProjectCache.from_cache_dir(download_base)
abc_cache.list_data_files('WMB-10Xv2')
# Out:
# /home/momo/miniforge3/envs/abca-env/lib/python3.10/site-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:630: OutdatedManifestWarning: You are loading releases/20241130/manifest.json. A more up to date version of the dataset -- releases/20250531/manifest.json -- exists online. To see the changes between the two versions of the dataset, run
# type.compare_manifests('releases/20241130/manifest.json', 'releases/20250531/manifest.json')
# To load another version of the dataset, run
# type.load_manifest('releases/20250531/manifest.json')
#   warnings.warn(msg, OutdatedManifestWarning)
# ['WMB-10Xv2-CTXsp/log2',
#  'WMB-10Xv2-CTXsp/raw',
#  'WMB-10Xv2-HPF/log2',
#  'WMB-10Xv2-HPF/raw',
#  'WMB-10Xv2-HY/log2',
#  'WMB-10Xv2-HY/raw',
#  'WMB-10Xv2-Isocortex-1/log2',
#  'WMB-10Xv2-Isocortex-1/raw',
#  'WMB-10Xv2-Isocortex-2/log2',
#  'WMB-10Xv2-Isocortex-2/raw',
#  'WMB-10Xv2-Isocortex-3/log2',
#  'WMB-10Xv2-Isocortex-3/raw',
#  'WMB-10Xv2-Isocortex-4/log2',
#  'WMB-10Xv2-Isocortex-4/raw',
#  'WMB-10Xv2-MB/log2',
#  'WMB-10Xv2-MB/raw',
#  'WMB-10Xv2-OLF/log2',
#  'WMB-10Xv2-OLF/raw',
#  'WMB-10Xv2-TH/log2',
#  'WMB-10Xv2-TH/raw']

# %%
for dataset in abc_cache.list_data_files('WMB-10Xv2'):
    if not dataset.endswith("log2"):
        abc_cache.get_data_path(directory='WMB-10Xv2', file_name=dataset)
# Out:
# WMB-10Xv2-CTXsp-raw.h5ad: 100%|██████████| 1.73G/1.73G [00:29<00:00, 58.0MMB/s]
# WMB-10Xv2-HPF-raw.h5ad: 100%|██████████| 6.10G/6.10G [02:28<00:00, 41.0MMB/s]
# WMB-10Xv2-HY-raw.h5ad: 100%|██████████| 2.91G/2.91G [00:57<00:00, 50.9MMB/s]
# WMB-10Xv2-Isocortex-1-raw.h5ad: 100%|██████████| 8.60G/8.60G [02:52<00:00, 49.7MMB/s]
# WMB-10Xv2-Isocortex-2-raw.h5ad: 100%|██████████| 9.44G/9.44G [03:06<00:00, 50.7MMB/s]
# WMB-10Xv2-Isocortex-3-raw.h5ad: 100%|██████████| 8.46G/8.46G [04:15<00:00, 33.1MMB/s]
# WMB-10Xv2-Isocortex-4-raw.h5ad: 100%|██████████| 8.69G/8.69G [02:48<00:00, 51.6MMB/s]
# WMB-10Xv2-MB-raw.h5ad: 100%|██████████| 811M/811M [00:15<00:00, 52.4MMB/s]
# WMB-10Xv2-OLF-raw.h5ad: 100%|██████████| 5.13G/5.13G [01:30<00:00, 57.0MMB/s]
# WMB-10Xv2-TH-raw.h5ad: 100%|██████████| 4.04G/4.04G [01:15<00:00, 53.5MMB/s]

# %%
# Loading datasets one by one
for dataset in abc_cache.list_data_files('WMB-10Xv2'):
    if not dataset.endswith("log2"):
        data_path = abc_cache.get_data_path(directory='WMB-10Xv2', file_name=dataset)
        print(f"Loading : {data_path}")
# Out:
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-CTXsp-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HPF-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HY-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-1-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-2-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-3-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-4-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-MB-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-OLF-raw.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-TH-raw.h5ad

# %%
cell_metadata = abc_cache.get_metadata_dataframe(
    directory='WMB-10X',
    file_name='cell_metadata_with_cluster_annotation'
)
cell_metadata.set_index('cell_label', inplace=True)
# Out:
# /home/momo/miniforge3/envs/abca-env/lib/python3.10/site-packages/abc_atlas_access/abc_atlas_cache/abc_project_cache.py:429: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path, **kwargs)

# %%
# Adding metadata to the AnnData objects
for dataset in abc_cache.list_data_files('WMB-10Xv2'):
    if not dataset.endswith("log2"):
        # Path to the dataset
        data_path = abc_cache.get_data_path(directory='WMB-10Xv2', file_name=dataset)
        print(f"Loading : {data_path}")

        # Load expression data
        expression_data = sc.read_h5ad(data_path)

        # Align metadata with expression data
        common_cells = expression_data.obs_names.intersection(cell_metadata.index)
        expression_data = expression_data[common_cells, :]

        # Add metadata to the AnnData object
        expression_data.obs = cell_metadata.loc[common_cells]

        # Save the modified dataset
        new_file_name = data_path.with_name(data_path.stem + '-wmeta.h5ad')
        print("Saving to: ", new_file_name)
        expression_data.write_h5ad(new_file_name)

        del expression_data
# Out:
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-CTXsp-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-CTXsp-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HPF-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HPF-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HY-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HY-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-1-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-1-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-2-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-2-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-3-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-3-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-4-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-4-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-MB-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-MB-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-OLF-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-OLF-raw-wmeta.h5ad
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-TH-raw.h5ad
# Saving to:  /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-TH-raw-wmeta.h5ad

# %%
# Subsetting data to microglia

# Define the specific subclass name to filter
specific_subclass = '334 Microglia NN'

# Initialize an empty list to store filtered AnnData objects
filtered_datasets = []

# Loop over the datasets
for dataset in abc_cache.list_data_files('WMB-10Xv2'):
    if not dataset.endswith("log2"):
        # Path to the dataset
        data_path = abc_cache.get_data_path(directory='WMB-10Xv2', file_name=dataset)
        new_file_name = data_path.with_name(data_path.stem + '-wmeta.h5ad')
        print(f"Loading : {new_file_name}")

        # Load expression data
        expression_data = sc.read_h5ad(new_file_name)

        # Filter cells based on the specific subclass
        filtered_data = expression_data[expression_data.obs['subclass'] == specific_subclass]
        print("Shape of filtered data: ", filtered_data.shape)

        # Append the filtered data to the list
        filtered_datasets.append(filtered_data)
        
        del expression_data

# Concatenate all filtered datasets into one
combined_dataset = filtered_datasets[0].concatenate(*filtered_datasets[1:])
combined_dataset
# Out:
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-CTXsp-raw-wmeta.h5ad
# Shape of filtered data:  (140, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HPF-raw-wmeta.h5ad
# Shape of filtered data:  (419, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-HY-raw-wmeta.h5ad
# Shape of filtered data:  (79, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-1-raw-wmeta.h5ad
# Shape of filtered data:  (129, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-2-raw-wmeta.h5ad
# Shape of filtered data:  (0, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-3-raw-wmeta.h5ad
# Shape of filtered data:  (0, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Isocortex-4-raw-wmeta.h5ad
# Shape of filtered data:  (1068, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-MB-raw-wmeta.h5ad
# Shape of filtered data:  (44, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-OLF-raw-wmeta.h5ad
# Shape of filtered data:  (2747, 32285)
# Loading : /data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-TH-raw-wmeta.h5ad
# Shape of filtered data:  (134, 32285)
# /tmp/ipykernel_617278/1010917863.py:30: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combined_dataset = filtered_datasets[0].concatenate(*filtered_datasets[1:])
# AnnData object with n_obs × n_vars = 4760 × 32285
#     obs: 'cell_barcode', 'barcoded_cell_sample_label', 'library_label', 'feature_matrix_label', 'entity', 'brain_section_label', 'library_method', 'region_of_interest_acronym', 'donor_label', 'donor_genotype', 'donor_sex', 'dataset_label', 'x', 'y', 'cluster_alias', 'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color', 'class_color', 'subclass_color', 'supertype_color', 'cluster_color', 'region_of_interest_order', 'region_of_interest_color', 'batch'
#     var: 'gene_symbol'

# %%
combined_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/WMB-10Xv2/20230630/WMB-10Xv2-Microglia-raw-wmeta.h5ad'
combined_dataset.write_h5ad(combined_path)
