# %%
import anndata
import gc
import scanpy as sc
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
download_base = Path('/data/scRNA/ABCA/AIBS/AWS/')
abc_cache = AbcProjectCache.from_cache_dir(download_base)
# Out:
# /home/momo/miniforge3/envs/abca-env/lib/python3.10/site-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:630: OutdatedManifestWarning: You are loading releases/20241130/manifest.json. A more up to date version of the dataset -- releases/20250131/manifest.json -- exists online. To see the changes between the two versions of the dataset, run
# type.compare_manifests('releases/20241130/manifest.json', 'releases/20250131/manifest.json')
# To load another version of the dataset, run
# type.load_manifest('releases/20250131/manifest.json')
#   warnings.warn(msg, OutdatedManifestWarning)

# %%
cell = abc_cache.get_metadata_dataframe(
    directory='MERFISH-C57BL6J-638850',
    file_name='cell_metadata_with_cluster_annotation',
    dtype={"cell_label": str}
)
cell.set_index('cell_label', inplace=True)
print("Number of cells = ", len(cell))
cell.head(5)
# Out:
# Number of cells =  3938808
#                       brain_section_label  cluster_alias  \
# cell_label
# 1019171907102340387-1   C57BL6J-638850.37           1408
# 1104095349101460194-1   C57BL6J-638850.26           4218
# 1017092617101450577     C57BL6J-638850.25           4218
# 1018093344101130233     C57BL6J-638850.13           4218
# 1019171912201610094     C57BL6J-638850.27           4218
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1019171907102340387-1                   0.596276       C57BL6J-638850
# 1104095349101460194-1                   0.641180       C57BL6J-638850
# 1017092617101450577                     0.763531       C57BL6J-638850
# 1018093344101130233                     0.558073       C57BL6J-638850
# 1019171912201610094                     0.591009       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1019171907102340387-1  C57BL6J-638850          wt/wt         M  7.226245
# 1104095349101460194-1  C57BL6J-638850          wt/wt         M  5.064889
# 1017092617101450577    C57BL6J-638850          wt/wt         M  5.792921
# 1018093344101130233    C57BL6J-638850          wt/wt         M  3.195950
# 1019171912201610094    C57BL6J-638850          wt/wt         M  5.635732
#
#                               y    z neurotransmitter           class  \
# cell_label
# 1019171907102340387-1  4.148963  6.6              NaN  04 DG-IMN Glut
# 1104095349101460194-1  7.309543  4.2             Glut       23 P Glut
# 1017092617101450577    8.189973  4.0             Glut       23 P Glut
# 1018093344101130233    5.868655  2.4             Glut       23 P Glut
# 1019171912201610094    7.995842  4.4             Glut       23 P Glut
#
#                                        subclass                    supertype  \
# cell_label
# 1019171907102340387-1         038 DG-PIR Ex IMN         0141 DG-PIR Ex IMN_2
# 1104095349101460194-1  235 PG-TRN-LRN Fat2 Glut  0953 PG-TRN-LRN Fat2 Glut_1
# 1017092617101450577    235 PG-TRN-LRN Fat2 Glut  0953 PG-TRN-LRN Fat2 Glut_1
# 1018093344101130233    235 PG-TRN-LRN Fat2 Glut  0953 PG-TRN-LRN Fat2 Glut_1
# 1019171912201610094    235 PG-TRN-LRN Fat2 Glut  0953 PG-TRN-LRN Fat2 Glut_1
#
#                                            cluster neurotransmitter_color  \
# cell_label
# 1019171907102340387-1         0515 DG-PIR Ex IMN_2                #666666
# 1104095349101460194-1  4199 PG-TRN-LRN Fat2 Glut_1                #2B93DF
# 1017092617101450577    4199 PG-TRN-LRN Fat2 Glut_1                #2B93DF
# 1018093344101130233    4199 PG-TRN-LRN Fat2 Glut_1                #2B93DF
# 1019171912201610094    4199 PG-TRN-LRN Fat2 Glut_1                #2B93DF
#
#                       class_color subclass_color supertype_color cluster_color
# cell_label
# 1019171907102340387-1     #16f2f2        #3D53CC         #CC7A3D       #73FFBF
# 1104095349101460194-1     #6b5ca5        #9B7ACC         #990041       #663D63
# 1017092617101450577       #6b5ca5        #9B7ACC         #990041       #663D63
# 1018093344101130233       #6b5ca5        #9B7ACC         #990041       #663D63
# 1019171912201610094       #6b5ca5        #9B7ACC         #990041       #663D63

# %%
# expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/MERFISH-C57BL6J-638850/20230830/C57BL6J-638850-raw.h5ad'
expr_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/MERFISH-C57BL6J-638850-imputed/20240831/C57BL6J-638850-imputed-log2.h5ad'
expression_data = sc.read_h5ad(expr_path)
expression_data
# Out:
# AnnData object with n_obs × n_vars = 4334174 × 8460
#     obs: 'brain_section_label'
#     var: 'gene_symbol'

# %%
# Align metadata with expression data
common_cells = expression_data.obs_names.intersection(cell.index)
expression_data = expression_data[common_cells, :]

# Add metadata to the AnnData object
expression_data.obs = cell.loc[common_cells]
expression_data
# Out:
# AnnData object with n_obs × n_vars = 3938808 × 8460
#     obs: 'brain_section_label', 'cluster_alias', 'average_correlation_score', 'feature_matrix_label', 'donor_label', 'donor_genotype', 'donor_sex', 'x', 'y', 'z', 'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color', 'class_color', 'subclass_color', 'supertype_color', 'cluster_color'
#     var: 'gene_symbol'

# %%
expression_data.obs.head()
# Out:
#                       brain_section_label  cluster_alias  \
# cell_label
# 1104095349100540743-1   C57BL6J-638850.52            128
# 1018093345100600265     C57BL6J-638850.45            128
# 1018135614102090183     C57BL6J-638850.55            128
# 1104095348100570634     C57BL6J-638850.46            128
# 1018122109102452991     C57BL6J-638850.51            128
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1104095349100540743-1                   0.601714       C57BL6J-638850
# 1018093345100600265                     0.601081       C57BL6J-638850
# 1018135614102090183                     0.524031       C57BL6J-638850
# 1104095348100570634                     0.649367       C57BL6J-638850
# 1018122109102452991                     0.539654       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1104095349100540743-1  C57BL6J-638850          wt/wt         M  2.523144
# 1018093345100600265    C57BL6J-638850          wt/wt         M  1.934682
# 1018135614102090183    C57BL6J-638850          wt/wt         M  8.025767
# 1104095348100570634    C57BL6J-638850          wt/wt         M  8.999382
# 1018122109102452991    C57BL6J-638850          wt/wt         M  8.487662
#
#                               y     z neurotransmitter          class  \
# cell_label
# 1104095349100540743-1  5.745040   9.8             Glut  01 IT-ET Glut
# 1018093345100600265    6.106153   8.2             Glut  01 IT-ET Glut
# 1018135614102090183    5.027320  10.4             Glut  01 IT-ET Glut
# 1104095348100570634    5.999297   8.4             Glut  01 IT-ET Glut
# 1018122109102452991    6.059709   9.6             Glut  01 IT-ET Glut
#
#                                         subclass  \
# cell_label
# 1104095349100540743-1  001 CLA-EPd-CTX Car3 Glut
# 1018093345100600265    001 CLA-EPd-CTX Car3 Glut
# 1018135614102090183    001 CLA-EPd-CTX Car3 Glut
# 1104095348100570634    001 CLA-EPd-CTX Car3 Glut
# 1018122109102452991    001 CLA-EPd-CTX Car3 Glut
#
#                                           supertype  \
# cell_label
# 1104095349100540743-1  0001 CLA-EPd-CTX Car3 Glut_1
# 1018093345100600265    0001 CLA-EPd-CTX Car3 Glut_1
# 1018135614102090183    0001 CLA-EPd-CTX Car3 Glut_1
# 1104095348100570634    0001 CLA-EPd-CTX Car3 Glut_1
# 1018122109102452991    0001 CLA-EPd-CTX Car3 Glut_1
#
#                                             cluster neurotransmitter_color  \
# cell_label
# 1104095349100540743-1  0001 CLA-EPd-CTX Car3 Glut_1                #2B93DF
# 1018093345100600265    0001 CLA-EPd-CTX Car3 Glut_1                #2B93DF
# 1018135614102090183    0001 CLA-EPd-CTX Car3 Glut_1                #2B93DF
# 1104095348100570634    0001 CLA-EPd-CTX Car3 Glut_1                #2B93DF
# 1018122109102452991    0001 CLA-EPd-CTX Car3 Glut_1                #2B93DF
#
#                       class_color subclass_color supertype_color cluster_color
# cell_label
# 1104095349100540743-1     #FA0087        #64c2fc         #99822E       #00664E
# 1018093345100600265       #FA0087        #64c2fc         #99822E       #00664E
# 1018135614102090183       #FA0087        #64c2fc         #99822E       #00664E
# 1104095348100570634       #FA0087        #64c2fc         #99822E       #00664E
# 1018122109102452991       #FA0087        #64c2fc         #99822E       #00664E

# %%
# Saving to file
# save_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/MERFISH-C57BL6J-638850/20230830/C57BL6J-638850-raw-wmeta.h5ad'
save_path = '/data/scRNA/ABCA/AIBS/AWS/expression_matrices/MERFISH-C57BL6J-638850-imputed/20240831/C57BL6J-638850-imputed-log2-wmeta.h5ad'
expression_data.write_h5ad(save_path)

# %%
del expression_data
